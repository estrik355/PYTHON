# %%
### Listas ##

#Definición

my_list = list()
my_other_list = [] # Estas dos lineas sirven para crear una lista.

print(len(my_list))

my_list = [35,24,62,52,30,30,17]

print(my_list)  #Inprime los valores de la lista.
print(len(my_list)) #Inmprime la logitud de la lista.

my_other_list = [35, 1.77, "Estrella", "Ortiz"]

print(type(my_list))  #Estas dos lineas imprimen el tipo; en este caso "Listas"
print(type(my_other_list))

#Acceso a elementos y búsqueda.

print(my_other_list[0])
print(my_other_list[1])
print(my_other_list[-1])
print(my_other_list[-4])
print(my_list.count(30))
#print(my_other_list[4]) #IndexError
#print(my_other_list[-5]) #IndexError

print(my_other_list.index ("Estrella"))

age, heigth, name, surname, = my_other_list
print(name)

name, height, name, surname = my_other_list[2], my_other_list[1], my_other_list[0], my_other_list[3]
print(age)

# Concatenación.

print(my_list + my_other_list) #Para concatenar se utliza el orperador (+)
#print(my_list - my_other_list)

# Creacion, inserción, actualización y eliminación.

my_other_list.append("CECyTEM")
print(my_other_list)

my_other_list.insert(1, "Rojo")
print(my_other_list)

my_other_list[1] = "Azul"
print(my_other_list)

my_list.remove(30)
print(my_list)

print(my_list.pop()) #El pop solito elimina el ultimo valor.
print(my_list)

my_pop_element = my_list.pop(2)
print(my_pop_element)
print(my_list)

del my_list[2]
print(my_list)

#Operaciones con listas.

my_new_list = my_list.cuppy
# Se creó una copia de "My_list" y toda la info se pasó a "My_new_list"

my_list.clear() #Clear = Eliminar.
print(my_list)
print(my_new_list)

my_new_list.reverse() #Cambiar todo al reves
print(my_new_list)

my_new_list.sort() # sort = ordenar
print(my_new_list)

#Sub listas

print(my_new_list[1:3])

#Cambio de tipo.

my_list = "Hola Python"
print(my_list)
print(type(my_list))
# Out:
# 0
# [35, 24, 62, 52, 30, 30, 17]
# 7
# <class 'list'>
# <class 'list'>
# 35
# 1.77
# Ortiz
# 35
# 2
# 2
# Estrella
# 35
# [35, 24, 62, 52, 30, 30, 17, 35, 1.77, 'Estrella', 'Ortiz']
# [35, 1.77, 'Estrella', 'Ortiz', 'CECyTEM']
# [35, 'Rojo', 1.77, 'Estrella', 'Ortiz', 'CECyTEM']
# [35, 'Azul', 1.77, 'Estrella', 'Ortiz', 'CECyTEM']
# [35, 24, 62, 52, 30, 17]
# 17
# [35, 24, 62, 52, 30]
# 62
# [35, 24, 52, 30]
# [35, 24, 30]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-15-ffb32cf5578c> in <cell line: 69>()
#      67 #Operaciones con listas.
#      68
# ---> 69 my_new_list = my_list.cuppy
#      70 # Se creó una copia de "My_list" y toda la info se pasó a "My_new_list"
#      71
#
# AttributeError: 'list' object has no attribute 'cuppy'
