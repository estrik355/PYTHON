# %%
### Condicionals ###

# if

my_condicion = False

if my_condicion:  #Es lo mismo que if my_condicion == True
  print("Se ejecuta la condicion del if")

  my_condicion = 5*5

  if my_condicion == 10
   print("Se ejecuta la condicion del if")

  #if, elif, else.

if my_condicion > 10 and my_condicion < 20:
   print("Es mayor que 10 y menor que 20")
elif my_condicion == 25:
    #print("Es igual a 25")
else
  print("Es menor o igual que 10 o mayor o igual que 20 o distinto de 25")

print("La ejecucion continúa")

# Condicional con ispección de valor

my_string = ""

if not my_string:  #Cuando una cadena no tiene texto su vslor boleano es falso. Y el "Not" cambia eso.
  print("Mi cadena de taxto está vacía")

if my_string == "Mi cadena de textooo":
 print("Estas cadenas de texto cionciden")
# Out:
# Estas cadenas de texto cionciden
